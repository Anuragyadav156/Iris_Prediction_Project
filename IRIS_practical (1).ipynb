# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r"C:\Users\annu\Downloads\IRIS.csv")

print(data.shape)
# Out:
# (150, 5)

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize = (12,6))
sns.lineplot(data = data)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x=data["sepal_length"], y = data["petal_length"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
plt.figure(figsize = (10,5))
sns.regplot(x=data["sepal_length"], y = data["petal_length"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x=data["sepal_length"], y = data["petal_length"], hue = data["sepal_width"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
plt.figure(figsize = (6,8))
sns.lmplot(x= "sepal_length", y = "petal_length", hue = "sepal_width", data = data)

# %%
plt.figure(figsize = (10,5))
sns.swarmplot(x=data["sepal_length"], y = data["petal_length"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
y = data["species"]
x = data.drop(columns="species")
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
Iris_data =  data.drop(columns = "species")
Iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
plt.figure(figsize = (20,10))
sns.heatmap(data= Iris_data, annot = True)
# Out:
# <Axes: >

# %%
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
# To split testing data from training data
X_train, X_test, y_train, y_test= train_test_split(x,y,test_size=0.3, random_state=1)

# %%
base_classifier = DecisionTreeClassifier(max_depth=3)
adaboost_classifier = AdaBoostClassifier(base_classifier, n_estimators=50, random_state=42)
adaboost_classifier.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=3),
#                    random_state=42)

# %%
y_pred = adaboost_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9777777777777777
